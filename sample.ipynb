# %%
def twinPrimes :=
  matchAll primes as list integer with
    | _ ++ $p :: #(p + 2) :: _ -> (p, p + 2)

# %%
take 10 twinPrimes
# Out:
# $$\{(3, 5), (5, 7), (11, 13), (17, 19), (29, 31), (41, 43), (59, 61), (71, 73), (101, 103), (107, 109)\}$$

# %%
(+ x y)
# Out:
# $$x + y$$

# %%
(* x y)
# Out:
# $$x y$$

# %%
(** (+ x y) 2)
# Out:
# $$x^2 + 2 x y + y^2$$

# %%
(** (+ x y) 5)
# Out:
# $$x^5 + 5 x^4 y + 10 x^3 y^2 + 10 x^2 y^3 + 5 x y^4 + y^5$$

# %%
(-1 + sqrt 17 + sqrt (34 - 2 * sqrt 17) + 2 * sqrt (17 + 3 * sqrt 17 - sqrt (34 - 2 * sqrt 17) - 2 * sqrt (34 + 2 * sqrt 17))) / 8
# Out:
# $$\frac{-1 + \sqrt{17} + \sqrt{34 - 2 \sqrt{17}} + 2 \sqrt{17 + 3 \sqrt{17} - \sqrt{34 - 2 \sqrt{17}} - 2 \sqrt{34 + 2 \sqrt{17}}}}{8}$$

# %%
[| [| 1, 2, 3 |], [| 4, 5, 6 |] |]
# Out:
# $$\{\{1, 2, 3\}, \{4, 5, 6\}\}$$

# %%
(`(a + b) + 2) ^ 2
# Out:
# $$(a + b)^2 + 4 (a + b) + 4$$
